# %%
import pandas as pd
import tensorflow as tf
import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# C:\Users\Thivyan\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
 # Give dataset path
train_directory = 'train'
test_directory = 'test'

# %% [markdown]
# ### Dataset creation

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
                train_directory,
                subset='training',
                color_mode='rgb',
                batch_size=10,
                image_size=(256, 256),
                shuffle=True,
                seed=100,
                validation_split=0.2)
# Out:
# Found 135 files belonging to 3 classes.
# Using 108 files for training.

# %%
valid_dataset = tf.keras.utils.image_dataset_from_directory(
                train_directory,
                subset='validation',
                color_mode='rgb',
                batch_size=4,
                image_size=(256, 256),
                shuffle=True,
                seed=100,
                validation_split=0.2)
# Out:
# Found 135 files belonging to 3 classes.
# Using 27 files for validation.

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['A', 'B', 'C']

# %% [markdown]
# ### Image Visualization

# %%
fig = plt.figure(figsize=(20,10))

for img, labels in train_dataset.take(17):
    for i in range(9):
        try:
            ax = plt.subplot(3,3,i+1)
            plt.imshow(img[i].numpy().astype('uint8'))
            plt.title(class_names[labels[i]])
            plt.axis('off')
        except Exception as e:  # in the interest in keeping the output clean...
                pass

# %% [markdown]
# ### Data Augmentation

# %%
train_datagen = ImageDataGenerator(
                          rotation_range=40,
                          width_shift_range=0.2,
                          height_shift_range=0.2,
                          rescale=1./255,
                          shear_range=0.2,
                          zoom_range=0.2,
                          horizontal_flip=True,
                          fill_mode='reflect')

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_set = train_datagen.flow_from_directory(
                                    train_directory,
                                    target_size=(256, 256),
                                    color_mode='rgb',
                                    class_mode='categorical',
                                    batch_size=32)
# Out:
# Found 135 images belonging to 3 classes.

# %%
valid_set = train_datagen.flow_from_directory(
                                    test_directory,
                                    target_size=(256, 256),
                                    color_mode='rgb',
                                    class_mode='categorical',
                                    batch_size=32)
# Out:
# Found 30 images belonging to 3 classes.

# %% [markdown]
# ### Model Creation - CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.callbacks import ModelCheckpoint
from keras import models

# %%
model = Sequential()

# %%
# Layer creation
model.add(Conv2D(filters=16, kernel_size=3, padding='same', activation='relu', 
                 input_shape=(256,256,3)))
model.add(MaxPooling2D(pool_size=2))


model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
          

model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
      

model.add(Conv2D(filters=128, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
         

model.add(Conv2D(filters=256, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
         

model.add(Conv2D(filters=512, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))          


model.add(Flatten())

model.add(Dense(700, activation='relu'))
model.add(Dropout(0.4))

model.add(Dense(200, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(3, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer = (tf.keras.optimizers.Adam(learning_rate=0.0001)), 
              metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 256)       295168
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 700)               5735100
#
#  dropout (Dropout)           (None, 700)               0
#
#  dense_1 (Dense)             (None, 200)               140200
#
#  dense_2 (Dense)             (None, 100)               20100
#
#  dense_3 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 7,468,471
# Trainable params: 7,468,471
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint(filepath = 'signlanguage.h5', verbose = 1, save_best_only=True)

# %%
# %%time
model_train = model.fit(train_set, 
                        epochs=100, 
                        batch_size = 32,
                        validation_data = valid_set, 
                        callbacks=[checkpoint],
                        verbose = 1)
# Out:
# Epoch 1/100
# 5/5 [==============================] - ETA: 0s - loss: 1.0995 - accuracy: 0.2889
# Epoch 1: val_loss improved from inf to 1.09063, saving model to signlanguage.h5
# 5/5 [==============================] - 8s 1s/step - loss: 1.0995 - accuracy: 0.2889 - val_loss: 1.0906 - val_accuracy: 0.3667
# Epoch 2/100
# 5/5 [==============================] - ETA: 0s - loss: 1.0976 - accuracy: 0.3185
# Epoch 2: val_loss improved from 1.09063 to 1.08329, saving model to signlanguage.h5
# 5/5 [==============================] - 7s 1s/step - loss: 1.0976 - accuracy: 0.3185 - val_loss: 1.0833 - val_accuracy: 0.3333
# Epoch 3/100
# 5/5 [==============================] - ETA: 0s - loss: 1.0857 - accuracy: 0.4667
# Epoch 3: val_loss improved from 1.08329 to 1.07462, saving model to signlanguage.h5
# 5/5 [==============================] - 7s 1s/step - loss: 1.0857 - accuracy: 0.4667 - val_loss: 1.0746 - val_accuracy: 0.3333
# Epoch 4/100
# 5/5 [==============================] - ETA: 0s - loss: 1.0710 - accuracy: 0.5185
# Epoch 4: val_loss improved from 1.07462 to 1.06335, saving model to signlanguage.h5
# 5/5 [==============================] - 7s 1s/step - loss: 1.0710 - accuracy: 0.5185 - val_loss: 1.0634 - val_accuracy: 0.6000
# Epoch 5/100
# 5/5 [==============================] - ETA: 0s - loss: 1.0634 - accuracy: 0.3704
# Epoch 5: val_loss improved from 1.06335 to 1.04251, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 1.0634 - accuracy: 0.3704 - val_loss: 1.0425 - val_accuracy: 0.3333
# Epoch 6/100
# 5/5 [==============================] - ETA: 0s - loss: 1.0239 - accuracy: 0.5481
# Epoch 6: val_loss improved from 1.04251 to 0.97431, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 1.0239 - accuracy: 0.5481 - val_loss: 0.9743 - val_accuracy: 0.6000
# Epoch 7/100
# 5/5 [==============================] - ETA: 0s - loss: 0.9632 - accuracy: 0.6889
# Epoch 7: val_loss improved from 0.97431 to 0.90797, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.9632 - accuracy: 0.6889 - val_loss: 0.9080 - val_accuracy: 0.6333
# Epoch 8/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8452 - accuracy: 0.6519
# Epoch 8: val_loss improved from 0.90797 to 0.79707, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.8452 - accuracy: 0.6519 - val_loss: 0.7971 - val_accuracy: 0.6667
# Epoch 9/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7231 - accuracy: 0.7481
# Epoch 9: val_loss improved from 0.79707 to 0.62192, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.7231 - accuracy: 0.7481 - val_loss: 0.6219 - val_accuracy: 0.7667
# Epoch 10/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5774 - accuracy: 0.7556
# Epoch 10: val_loss improved from 0.62192 to 0.55402, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.5774 - accuracy: 0.7556 - val_loss: 0.5540 - val_accuracy: 0.7333
# Epoch 11/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.6963
# Epoch 11: val_loss improved from 0.55402 to 0.46431, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.4907 - accuracy: 0.6963 - val_loss: 0.4643 - val_accuracy: 0.6667
# Epoch 12/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4988 - accuracy: 0.6889
# Epoch 12: val_loss did not improve from 0.46431
# 5/5 [==============================] - 6s 1s/step - loss: 0.4988 - accuracy: 0.6889 - val_loss: 0.7629 - val_accuracy: 0.7333
# Epoch 13/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4949 - accuracy: 0.7037
# Epoch 13: val_loss did not improve from 0.46431
# 5/5 [==============================] - 6s 1s/step - loss: 0.4949 - accuracy: 0.7037 - val_loss: 0.4783 - val_accuracy: 0.6667
# Epoch 14/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4861 - accuracy: 0.7185
# Epoch 14: val_loss improved from 0.46431 to 0.42257, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.4861 - accuracy: 0.7185 - val_loss: 0.4226 - val_accuracy: 0.8667
# Epoch 15/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4396 - accuracy: 0.7407
# Epoch 15: val_loss improved from 0.42257 to 0.40846, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.4396 - accuracy: 0.7407 - val_loss: 0.4085 - val_accuracy: 0.9333
# Epoch 16/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4469 - accuracy: 0.7037
# Epoch 16: val_loss did not improve from 0.40846
# 5/5 [==============================] - 6s 1s/step - loss: 0.4469 - accuracy: 0.7037 - val_loss: 0.4410 - val_accuracy: 0.7000
# Epoch 17/100
# 5/5 [==============================] - ETA: 0s - loss: 0.3735 - accuracy: 0.8148
# Epoch 17: val_loss improved from 0.40846 to 0.32993, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.3735 - accuracy: 0.8148 - val_loss: 0.3299 - val_accuracy: 0.9000
# Epoch 18/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4059 - accuracy: 0.7852
# Epoch 18: val_loss did not improve from 0.32993
# 5/5 [==============================] - 6s 1s/step - loss: 0.4059 - accuracy: 0.7852 - val_loss: 0.3831 - val_accuracy: 0.8000
# Epoch 19/100
# 5/5 [==============================] - ETA: 0s - loss: 0.3672 - accuracy: 0.8296
# Epoch 19: val_loss did not improve from 0.32993
# 5/5 [==============================] - 6s 1s/step - loss: 0.3672 - accuracy: 0.8296 - val_loss: 0.3857 - val_accuracy: 0.9333
# Epoch 20/100
# 5/5 [==============================] - ETA: 0s - loss: 0.3251 - accuracy: 0.8667
# Epoch 20: val_loss did not improve from 0.32993
# 5/5 [==============================] - 6s 1s/step - loss: 0.3251 - accuracy: 0.8667 - val_loss: 0.4757 - val_accuracy: 0.8667
# Epoch 21/100
# 5/5 [==============================] - ETA: 0s - loss: 0.3070 - accuracy: 0.8593
# Epoch 21: val_loss improved from 0.32993 to 0.28888, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.3070 - accuracy: 0.8593 - val_loss: 0.2889 - val_accuracy: 0.9333
# Epoch 22/100
# 5/5 [==============================] - ETA: 0s - loss: 0.2619 - accuracy: 0.9037
# Epoch 22: val_loss improved from 0.28888 to 0.19417, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.2619 - accuracy: 0.9037 - val_loss: 0.1942 - val_accuracy: 0.9667
# Epoch 23/100
# 5/5 [==============================] - ETA: 0s - loss: 0.2888 - accuracy: 0.8963
# Epoch 23: val_loss did not improve from 0.19417
# 5/5 [==============================] - 6s 1s/step - loss: 0.2888 - accuracy: 0.8963 - val_loss: 0.3737 - val_accuracy: 0.8333
# Epoch 24/100
# 5/5 [==============================] - ETA: 0s - loss: 0.2074 - accuracy: 0.9481
# Epoch 24: val_loss did not improve from 0.19417
# 5/5 [==============================] - 6s 1s/step - loss: 0.2074 - accuracy: 0.9481 - val_loss: 0.6309 - val_accuracy: 0.8333
# Epoch 25/100
# 5/5 [==============================] - ETA: 0s - loss: 0.2543 - accuracy: 0.8889
# Epoch 25: val_loss did not improve from 0.19417
# 5/5 [==============================] - 6s 1s/step - loss: 0.2543 - accuracy: 0.8889 - val_loss: 0.5753 - val_accuracy: 0.8000
# Epoch 26/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4404 - accuracy: 0.8444
# Epoch 26: val_loss improved from 0.19417 to 0.14363, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.4404 - accuracy: 0.8444 - val_loss: 0.1436 - val_accuracy: 0.9333
# Epoch 27/100
# 5/5 [==============================] - ETA: 0s - loss: 0.2670 - accuracy: 0.9037
# Epoch 27: val_loss did not improve from 0.14363
# 5/5 [==============================] - 6s 1s/step - loss: 0.2670 - accuracy: 0.9037 - val_loss: 0.2016 - val_accuracy: 0.9000
# Epoch 28/100
# 5/5 [==============================] - ETA: 0s - loss: 0.1956 - accuracy: 0.9111
# Epoch 28: val_loss did not improve from 0.14363
# 5/5 [==============================] - 6s 1s/step - loss: 0.1956 - accuracy: 0.9111 - val_loss: 0.7137 - val_accuracy: 0.7333
# Epoch 29/100
# 5/5 [==============================] - ETA: 0s - loss: 0.2088 - accuracy: 0.9037
# Epoch 29: val_loss did not improve from 0.14363
# 5/5 [==============================] - 6s 1s/step - loss: 0.2088 - accuracy: 0.9037 - val_loss: 0.1939 - val_accuracy: 0.9000
# Epoch 30/100
# 5/5 [==============================] - ETA: 0s - loss: 0.2373 - accuracy: 0.9037
# Epoch 30: val_loss did not improve from 0.14363
# 5/5 [==============================] - 6s 1s/step - loss: 0.2373 - accuracy: 0.9037 - val_loss: 0.1717 - val_accuracy: 0.9333
# Epoch 31/100
# 5/5 [==============================] - ETA: 0s - loss: 0.1862 - accuracy: 0.9111
# Epoch 31: val_loss did not improve from 0.14363
# 5/5 [==============================] - 6s 1s/step - loss: 0.1862 - accuracy: 0.9111 - val_loss: 0.5153 - val_accuracy: 0.8333
# Epoch 32/100
# 5/5 [==============================] - ETA: 0s - loss: 0.1585 - accuracy: 0.9630
# Epoch 32: val_loss did not improve from 0.14363
# 5/5 [==============================] - 6s 1s/step - loss: 0.1585 - accuracy: 0.9630 - val_loss: 0.3821 - val_accuracy: 0.8000
# Epoch 33/100
# 5/5 [==============================] - ETA: 0s - loss: 0.1263 - accuracy: 0.9630
# Epoch 33: val_loss did not improve from 0.14363
# 5/5 [==============================] - 6s 1s/step - loss: 0.1263 - accuracy: 0.9630 - val_loss: 0.5039 - val_accuracy: 0.8667
# Epoch 34/100
# 5/5 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9333
# Epoch 34: val_loss did not improve from 0.14363
# 5/5 [==============================] - 6s 1s/step - loss: 0.1425 - accuracy: 0.9333 - val_loss: 0.1641 - val_accuracy: 0.9000
# Epoch 35/100
# 5/5 [==============================] - ETA: 0s - loss: 0.1580 - accuracy: 0.9333
# Epoch 35: val_loss did not improve from 0.14363
# 5/5 [==============================] - 6s 1s/step - loss: 0.1580 - accuracy: 0.9333 - val_loss: 0.2876 - val_accuracy: 0.9000
# Epoch 36/100
# 5/5 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.9704
# Epoch 36: val_loss did not improve from 0.14363
# 5/5 [==============================] - 6s 1s/step - loss: 0.1206 - accuracy: 0.9704 - val_loss: 0.4449 - val_accuracy: 0.8667
# Epoch 37/100
# 5/5 [==============================] - ETA: 0s - loss: 0.1362 - accuracy: 0.9333
# Epoch 37: val_loss improved from 0.14363 to 0.07827, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.1362 - accuracy: 0.9333 - val_loss: 0.0783 - val_accuracy: 0.9333
# Epoch 38/100
# 5/5 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9556
# Epoch 38: val_loss did not improve from 0.07827
# 5/5 [==============================] - 6s 1s/step - loss: 0.1134 - accuracy: 0.9556 - val_loss: 0.0940 - val_accuracy: 0.9667
# Epoch 39/100
# 5/5 [==============================] - ETA: 0s - loss: 0.1213 - accuracy: 0.9407
# Epoch 39: val_loss did not improve from 0.07827
# 5/5 [==============================] - 6s 1s/step - loss: 0.1213 - accuracy: 0.9407 - val_loss: 0.3157 - val_accuracy: 0.8667
# Epoch 40/100
# 5/5 [==============================] - ETA: 0s - loss: 0.1907 - accuracy: 0.9185
# Epoch 40: val_loss did not improve from 0.07827
# 5/5 [==============================] - 6s 1s/step - loss: 0.1907 - accuracy: 0.9185 - val_loss: 0.6669 - val_accuracy: 0.8000
# Epoch 41/100
# 5/5 [==============================] - ETA: 0s - loss: 0.1076 - accuracy: 0.9630
# Epoch 41: val_loss improved from 0.07827 to 0.07412, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.1076 - accuracy: 0.9630 - val_loss: 0.0741 - val_accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0924 - accuracy: 0.9778
# Epoch 42: val_loss did not improve from 0.07412
# 5/5 [==============================] - 6s 1s/step - loss: 0.0924 - accuracy: 0.9778 - val_loss: 0.1457 - val_accuracy: 0.9333
# Epoch 43/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0867 - accuracy: 0.9778
# Epoch 43: val_loss did not improve from 0.07412
# 5/5 [==============================] - 6s 1s/step - loss: 0.0867 - accuracy: 0.9778 - val_loss: 0.1127 - val_accuracy: 0.9333
# Epoch 44/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.9852
# Epoch 44: val_loss did not improve from 0.07412
# 5/5 [==============================] - 6s 1s/step - loss: 0.0604 - accuracy: 0.9852 - val_loss: 0.2854 - val_accuracy: 0.9000
# Epoch 45/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0926 - accuracy: 0.9704
# Epoch 45: val_loss did not improve from 0.07412
# 5/5 [==============================] - 6s 1s/step - loss: 0.0926 - accuracy: 0.9704 - val_loss: 0.0819 - val_accuracy: 0.9667
# Epoch 46/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9778
# Epoch 46: val_loss did not improve from 0.07412
# 5/5 [==============================] - 6s 1s/step - loss: 0.0591 - accuracy: 0.9778 - val_loss: 0.1374 - val_accuracy: 0.9333
# Epoch 47/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9778
# Epoch 47: val_loss did not improve from 0.07412
# 5/5 [==============================] - 6s 1s/step - loss: 0.0598 - accuracy: 0.9778 - val_loss: 0.1645 - val_accuracy: 0.9667
# Epoch 48/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9852
# Epoch 48: val_loss improved from 0.07412 to 0.04539, saving model to signlanguage.h5
# 5/5 [==============================] - 7s 1s/step - loss: 0.0331 - accuracy: 0.9852 - val_loss: 0.0454 - val_accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9852
# Epoch 49: val_loss did not improve from 0.04539
# 5/5 [==============================] - 6s 1s/step - loss: 0.0367 - accuracy: 0.9852 - val_loss: 0.2988 - val_accuracy: 0.8667
# Epoch 50/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0590 - accuracy: 0.9778
# Epoch 50: val_loss did not improve from 0.04539
# 5/5 [==============================] - 6s 1s/step - loss: 0.0590 - accuracy: 0.9778 - val_loss: 0.1247 - val_accuracy: 0.9333
# Epoch 51/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9852
# Epoch 51: val_loss did not improve from 0.04539
# 5/5 [==============================] - 6s 1s/step - loss: 0.0546 - accuracy: 0.9852 - val_loss: 0.0513 - val_accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9852
# Epoch 52: val_loss did not improve from 0.04539
# 5/5 [==============================] - 6s 1s/step - loss: 0.0393 - accuracy: 0.9852 - val_loss: 0.0920 - val_accuracy: 0.9667
# Epoch 53/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0437 - accuracy: 0.9852
# Epoch 53: val_loss did not improve from 0.04539
# 5/5 [==============================] - 6s 1s/step - loss: 0.0437 - accuracy: 0.9852 - val_loss: 0.4243 - val_accuracy: 0.9333
# Epoch 54/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0682 - accuracy: 0.9778
# Epoch 54: val_loss improved from 0.04539 to 0.02405, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.0682 - accuracy: 0.9778 - val_loss: 0.0241 - val_accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0763 - accuracy: 0.9852
# Epoch 55: val_loss did not improve from 0.02405
# 5/5 [==============================] - 6s 1s/step - loss: 0.0763 - accuracy: 0.9852 - val_loss: 0.0305 - val_accuracy: 0.9667
# Epoch 56/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0759 - accuracy: 0.9704
# Epoch 56: val_loss did not improve from 0.02405
# 5/5 [==============================] - 6s 1s/step - loss: 0.0759 - accuracy: 0.9704 - val_loss: 0.0853 - val_accuracy: 0.9667
# Epoch 57/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9926
# Epoch 57: val_loss did not improve from 0.02405
# 5/5 [==============================] - 6s 1s/step - loss: 0.0331 - accuracy: 0.9926 - val_loss: 0.1872 - val_accuracy: 0.9333
# Epoch 58/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9926
# Epoch 58: val_loss improved from 0.02405 to 0.01475, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.0273 - accuracy: 0.9926 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0797 - accuracy: 0.9778
# Epoch 59: val_loss did not improve from 0.01475
# 5/5 [==============================] - 6s 1s/step - loss: 0.0797 - accuracy: 0.9778 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9926
# Epoch 60: val_loss did not improve from 0.01475
# 5/5 [==============================] - 6s 1s/step - loss: 0.0299 - accuracy: 0.9926 - val_loss: 0.4711 - val_accuracy: 0.8000
# Epoch 61/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 1.0000
# Epoch 61: val_loss did not improve from 0.01475
# 5/5 [==============================] - 6s 1s/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.2865 - val_accuracy: 0.9000
# Epoch 62/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 0.9926
# Epoch 62: val_loss improved from 0.01475 to 0.01456, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.0219 - accuracy: 0.9926 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9926
# Epoch 63: val_loss did not improve from 0.01456
# 5/5 [==============================] - 6s 1s/step - loss: 0.0174 - accuracy: 0.9926 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9852
# Epoch 64: val_loss did not improve from 0.01456
# 5/5 [==============================] - 6s 1s/step - loss: 0.0432 - accuracy: 0.9852 - val_loss: 0.1085 - val_accuracy: 0.9667
# Epoch 65/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9926
# Epoch 65: val_loss did not improve from 0.01456
# 5/5 [==============================] - 6s 1s/step - loss: 0.0304 - accuracy: 0.9926 - val_loss: 0.1507 - val_accuracy: 0.9667
# Epoch 66/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9852
# Epoch 66: val_loss did not improve from 0.01456
# 5/5 [==============================] - 6s 1s/step - loss: 0.0236 - accuracy: 0.9852 - val_loss: 0.0681 - val_accuracy: 0.9667
# Epoch 67/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9926
# Epoch 67: val_loss did not improve from 0.01456
# 5/5 [==============================] - 6s 1s/step - loss: 0.0281 - accuracy: 0.9926 - val_loss: 0.0238 - val_accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9926
# Epoch 68: val_loss did not improve from 0.01456
# 5/5 [==============================] - 6s 1s/step - loss: 0.0143 - accuracy: 0.9926 - val_loss: 0.1116 - val_accuracy: 0.9333
# Epoch 69/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9852
# Epoch 69: val_loss did not improve from 0.01456
# 5/5 [==============================] - 6s 1s/step - loss: 0.0503 - accuracy: 0.9852 - val_loss: 0.0549 - val_accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9926
# Epoch 70: val_loss did not improve from 0.01456
# 5/5 [==============================] - 6s 1s/step - loss: 0.0329 - accuracy: 0.9926 - val_loss: 0.0266 - val_accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9852
# Epoch 71: val_loss did not improve from 0.01456
# 5/5 [==============================] - 6s 1s/step - loss: 0.0268 - accuracy: 0.9852 - val_loss: 0.2044 - val_accuracy: 0.9333
# Epoch 72/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.9852
# Epoch 72: val_loss did not improve from 0.01456
# 5/5 [==============================] - 6s 1s/step - loss: 0.0345 - accuracy: 0.9852 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0402 - accuracy: 0.9926
# Epoch 73: val_loss improved from 0.01456 to 0.00803, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.0402 - accuracy: 0.9926 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9926
# Epoch 74: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0160 - accuracy: 0.9926 - val_loss: 0.1750 - val_accuracy: 0.9667
# Epoch 75/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 75: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9852
# Epoch 76: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0360 - accuracy: 0.9852 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 77: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9333
# Epoch 78/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9926
# Epoch 78: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0152 - accuracy: 0.9926 - val_loss: 0.0747 - val_accuracy: 0.9667
# Epoch 79/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 79: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2737 - val_accuracy: 0.9333
# Epoch 80/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 80: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9667
# Epoch 81/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9778
# Epoch 81: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0401 - accuracy: 0.9778 - val_loss: 0.9027 - val_accuracy: 0.8000
# Epoch 82/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0558 - accuracy: 0.9778
# Epoch 82: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0558 - accuracy: 0.9778 - val_loss: 0.1916 - val_accuracy: 0.9333
# Epoch 83/100
# 5/5 [==============================] - ETA: 0s - loss: 0.3091 - accuracy: 0.9259
# Epoch 83: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.3091 - accuracy: 0.9259 - val_loss: 3.0436 - val_accuracy: 0.7000
# Epoch 84/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5146 - accuracy: 0.8519
# Epoch 84: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.5146 - accuracy: 0.8519 - val_loss: 0.1249 - val_accuracy: 0.9333
# Epoch 85/100
# 5/5 [==============================] - ETA: 0s - loss: 0.1290 - accuracy: 0.9481
# Epoch 85: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.1290 - accuracy: 0.9481 - val_loss: 0.4272 - val_accuracy: 0.8667
# Epoch 86/100
# 5/5 [==============================] - ETA: 0s - loss: 0.1741 - accuracy: 0.9333
# Epoch 86: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.1741 - accuracy: 0.9333 - val_loss: 0.3388 - val_accuracy: 0.8667
# Epoch 87/100
# 5/5 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9333
# Epoch 87: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.1422 - accuracy: 0.9333 - val_loss: 0.3009 - val_accuracy: 0.9333
# Epoch 88/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9926
# Epoch 88: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0468 - accuracy: 0.9926 - val_loss: 0.3252 - val_accuracy: 0.8667
# Epoch 89/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9630
# Epoch 89: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0998 - accuracy: 0.9630 - val_loss: 0.1156 - val_accuracy: 0.9667
# Epoch 90/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9852
# Epoch 90: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0518 - accuracy: 0.9852 - val_loss: 0.0404 - val_accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 1.0000
# Epoch 91: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.0907 - val_accuracy: 0.9667
# Epoch 92/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9926
# Epoch 92: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0255 - accuracy: 0.9926 - val_loss: 0.2688 - val_accuracy: 0.9333
# Epoch 93/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9852
# Epoch 93: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0395 - accuracy: 0.9852 - val_loss: 0.0475 - val_accuracy: 0.9667
# Epoch 94/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9778
# Epoch 94: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0574 - accuracy: 0.9778 - val_loss: 0.0260 - val_accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9926
# Epoch 95: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0224 - accuracy: 0.9926 - val_loss: 0.2450 - val_accuracy: 0.9000
# Epoch 96/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9926
# Epoch 96: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0252 - accuracy: 0.9926 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9926
# Epoch 97: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0176 - accuracy: 0.9926 - val_loss: 0.0250 - val_accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 98: val_loss did not improve from 0.00803
# 5/5 [==============================] - 6s 1s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.1077 - val_accuracy: 0.9667
# Epoch 99/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9926
# Epoch 99: val_loss improved from 0.00803 to 0.00769, saving model to signlanguage.h5
# 5/5 [==============================] - 6s 1s/step - loss: 0.0262 - accuracy: 0.9926 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 1.0000
# Epoch 100: val_loss did not improve from 0.00769
# 5/5 [==============================] - 6s 1s/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.0570 - val_accuracy: 0.9667
# Wall time: 9min 55s

# %%
model.load_weights('signlanguage.h5')

# %%
tscore = model.evaluate(train_set, verbose=0)
taccuracy = 100 * tscore[1]
tloss = 100 * tscore[0]
print('tscore : ', tscore)
print('tloss : ', tloss)
print('taccuracy : ', taccuracy)
# Out:
# tscore :  [0.005890397354960442, 1.0]
# tloss :  0.5890397354960442
# taccuracy :  100.0

# %%
vscore = model.evaluate(valid_set, verbose=0)
vaccuracy = 100 * vscore[1]
vloss = 100 * vscore[0]
print('vscore : ', vscore)
print("vloss : ", vloss)
print('vaccuracy : ', vaccuracy)
# Out:
# vscore :  [0.13569262623786926, 0.9333333373069763]
# vloss :  13.569262623786926
# vaccuracy :  93.33333373069763
