# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv(r"D:\Computer courses\Internship project\Kaggle Project\TSLA.csv")
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 1     2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 2     2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# 3     2010-07-07    3.280000    3.326000    2.996000    3.160000    3.160000
# 4     2010-07-08    3.228000    3.504000    3.114000    3.492000    3.492000
# ...          ...         ...         ...         ...         ...         ...
# 2838  2021-10-08  796.210022  796.380005  780.909973  785.489990  785.489990
# 2839  2021-10-11  787.650024  801.239990  785.500000  791.940002  791.940002
# 2840  2021-10-12  800.929993  812.320007  796.570007  805.719971  805.719971
# 2841  2021-10-13  810.469971  815.409973  805.780029  811.080017  811.080017
# 2842  2021-10-14  815.489990  820.250000  813.349976  818.320007  818.320007
#
#         Volume
# 0     41094000
# ...

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2843.000000  2843.000000  2843.000000  2843.000000  2843.000000
# mean    105.868475   108.031370   103.555733   105.924597   105.924597
# std     188.738974   192.483055   184.638617   188.836358   188.836358
# min       3.228000     3.326000     2.996000     3.160000     3.160000
# 25%      10.698000    11.026000    10.420000    10.727000    10.727000
# 50%      45.874001    46.493999    45.102001    45.916000    45.916000
# 75%      65.021000    66.251999    64.015001    65.275002    65.275002
# max     891.380005   900.400024   871.599976   883.090027   883.090027
#
#              Volume
# count  2.843000e+03
# mean   3.141524e+07
# std    2.841880e+07
# min    5.925000e+05
# 25%    1.251050e+07
# 50%    2.481500e+07
# 75%    4.012025e+07
# max    3.046940e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2843 entries, 0 to 2842
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2843 non-null   object
#  1   Open       2843 non-null   float64
#  2   High       2843 non-null   float64
#  3   Low        2843 non-null   float64
#  4   Close      2843 non-null   float64
#  5   Adj Close  2843 non-null   float64
#  6   Volume     2843 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 155.6+ KB

# %%
df.plot()
# Out:
# <Axes: >

# %%
df['High'].plot(figsize=(15,5))
# Out:
# <Axes: >

# %%
df.Date
# Out:
# 0       2010-07-01
# 1       2010-07-02
# 2       2010-07-06
# 3       2010-07-07
# 4       2010-07-08
#            ...
# 2838    2021-10-08
# 2839    2021-10-11
# 2840    2021-10-12
# 2841    2021-10-13
# 2842    2021-10-14
# Name: Date, Length: 2843, dtype: object

# %%
date = df.loc[df.Date >= '2020-01-01']
date
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 2392  2020-01-02   84.900002   86.139999   84.342003   86.052002   86.052002
# 2393  2020-01-03   88.099998   90.800003   87.384003   88.601997   88.601997
# 2394  2020-01-06   88.094002   90.311996   88.000000   90.307999   90.307999
# 2395  2020-01-07   92.279999   94.325996   90.671997   93.811996   93.811996
# 2396  2020-01-08   94.739998   99.697998   93.646004   98.428001   98.428001
# ...          ...         ...         ...         ...         ...         ...
# 2838  2021-10-08  796.210022  796.380005  780.909973  785.489990  785.489990
# 2839  2021-10-11  787.650024  801.239990  785.500000  791.940002  791.940002
# 2840  2021-10-12  800.929993  812.320007  796.570007  805.719971  805.719971
# 2841  2021-10-13  810.469971  815.409973  805.780029  811.080017  811.080017
# 2842  2021-10-14  815.489990  820.250000  813.349976  818.320007  818.320007
#
#          Volume
# 2392   47660500
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure, axis = plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()
axis.plot(date.Date, date.Open)

# %%
import seaborn as sns

# %%
sns.lineplot(x=date.Date, y=date.Open)
# Out:
# <Axes: xlabel='Date', ylabel='Open'>

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 1     2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 2     2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# 3     2010-07-07    3.280000    3.326000    2.996000    3.160000    3.160000
# 4     2010-07-08    3.228000    3.504000    3.114000    3.492000    3.492000
# ...          ...         ...         ...         ...         ...         ...
# 2838  2021-10-08  796.210022  796.380005  780.909973  785.489990  785.489990
# 2839  2021-10-11  787.650024  801.239990  785.500000  791.940002  791.940002
# 2840  2021-10-12  800.929993  812.320007  796.570007  805.719971  805.719971
# 2841  2021-10-13  810.469971  815.409973  805.780029  811.080017  811.080017
# 2842  2021-10-14  815.489990  820.250000  813.349976  818.320007  818.320007
#
#         Volume
# 0     41094000
# ...

# %%
pd.to_datetime(df['Date'])
# Out:
# 0      2010-07-01
# 1      2010-07-02
# 2      2010-07-06
# 3      2010-07-07
# 4      2010-07-08
#           ...
# 2838   2021-10-08
# 2839   2021-10-11
# 2840   2021-10-12
# 2841   2021-10-13
# 2842   2021-10-14
# Name: Date, Length: 2843, dtype: datetime64[ns]

# %%
df = df.set_index('Date', drop=True)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# 2010-07-07    3.280000    3.326000    2.996000    3.160000    3.160000
# 2010-07-08    3.228000    3.504000    3.114000    3.492000    3.492000
# ...                ...         ...         ...         ...         ...
# 2021-10-08  796.210022  796.380005  780.909973  785.489990  785.489990
# 2021-10-11  787.650024  801.239990  785.500000  791.940002  791.940002
# 2021-10-12  800.929993  812.320007  796.570007  805.719971  805.719971
# 2021-10-13  810.469971  815.409973  805.780029  811.080017  811.080017
# 2021-10-14  815.489990  820.250000  813.349976  818.320007  818.320007
#
#               Volume
# Date
# 2010-07-01  41094000
# 2010-07-02  25699000
# 2010-07-06  34334500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2843 entries, 2010-07-01 to 2021-10-14
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2843 non-null   float64
#  1   High       2843 non-null   float64
#  2   Low        2843 non-null   float64
#  3   Close      2843 non-null   float64
#  4   Adj Close  2843 non-null   float64
#  5   Volume     2843 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 155.5+ KB

# %%
df['High'].rolling(10).mean()
# Out:
# Date
# 2010-07-01           NaN
# 2010-07-02           NaN
# 2010-07-06           NaN
# 2010-07-07           NaN
# 2010-07-08           NaN
#                  ...
# 2021-10-08    795.037000
# 2021-10-11    795.260999
# 2021-10-12    796.928998
# 2021-10-13    799.119995
# 2021-10-14    802.231995
# Name: High, Length: 2843, dtype: float64

# %%
df.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500
# 2010-07-07  3.280  3.326  2.996  3.160      3.160  34608500
# 2010-07-08  3.228  3.504  3.114  3.492      3.492  38557000

# %%
df['Open:30_days_rolling'] = df['Open'].rolling(5).mean()
df.head(10)
# Out:
#              Open   High    Low  Close  Adj Close    Volume  \
# Date
# 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500
# 2010-07-07  3.280  3.326  2.996  3.160      3.160  34608500
# 2010-07-08  3.228  3.504  3.114  3.492      3.492  38557000
# 2010-07-09  3.516  3.580  3.310  3.480      3.480  20253000
# 2010-07-12  3.590  3.614  3.400  3.410      3.410  11012500
# 2010-07-13  3.478  3.728  3.380  3.628      3.628  13400500
# 2010-07-14  3.588  4.030  3.552  3.968      3.968  20976000
# 2010-07-15  3.988  4.300  3.800  3.978      3.978  18699000
#
#             Open:30_days_rolling
# Date
# 2010-07-01                   NaN
# 2010-07-02                   NaN
# 2010-07-06                   NaN
# 2010-07-07                   NaN
# 2010-07-08                4.0216
# 2010-07-09                3.7248
# 2010-07-12                3.5228
# ...

# %%
df[['Open', 'Open:30_days_rolling']].plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Simple Moving Average - SMA
# Eg. for rolling(5) as mentioned above, we take a set of 5 values, say 'Open', and find the average of these 5 values and give them at the 5th position. Thus, we can see that the first 4 has Nan value and 5th has the average of all 5 values.

# %% [markdown]
# # Cumulative Moving Average - CMA
# CMA, in a set of 'Open' column values, takes average value in a succession manner. for eg. the first value returns as Nan as its only one. second one is the average of first and second values. third is the average of first 3 values. 4th is the average of first 4 values. and so on.

# %%
df['Open'].expanding().mean().plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # EMA - Exponential Moving Average
# formula : ((Open - prev EMA) * alpha) + prev EMA
#
# first EMA = simple moving average, as we don't have any EMA initially
#
# * alpha = 2/(span+1)
# * span - rolling window
# * for above eg. its 2/(5+1) = 2/6 = 0.3333

# %%
df['EMA_0.1'] = df['Open'].ewm(alpha=0.1, adjust=False).mean()

# %%
df['EMA_0.3'] = df['Open'].ewm(alpha=0.3, adjust=False).mean()

# %%
df['EMA_0.5'] = df['Open'].ewm(alpha=0.5, adjust=False).mean()

# %%
df[['Open', 'EMA_0.1', 'EMA_0.3', 'EMA_0.5']].plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # EWMA - Exponential Weighted Moving Average
#
# EWMA(t) = a * x(t) + (1-a) EWMA(t-1)
#
# * a - weight
# * EWMA(t-1) - previous EWMA value
# * EWMA(t) - current EWMA value

# %%
df['EWMA_5days'] = df['Open'].ewm(span=5).mean()

# %%
df[['Open', 'EWMA_5days']].plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # ARIMA
# * AutoRegression - AR (PACF)
# * Moving Average - MA (ACF)
# * Integrated - I (Differencing)
# * AR + MA - ARMA - Good for forecasting like Sales but bad for Stocks
# * ACF/PACF - (Partial) Auto Correlation Function
# * ARIMA - AR + I + MA
#
# ##### MA = mean + (error term * one coefficient)

# %%
df1 = pd.read_csv(r"D:\Computer courses\Internship project\Kaggle Project\AirPassengers.csv")
df1
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %% [markdown]
# Auto Regression
# - uses regression alogorithm
# - old data is called lags
# - K value - no of lags - calculated using PACF
# - in correlation-lags plot, we have upper and lower bound. Correlations that are above these limits have high correlation and thus affecting the current value
# - this plot is called PACF graph

# %% [markdown]
# ARIMA or SARIMAX
# * good for stationary data
#
# Stationary data - mean value, Standard Deviation are constant

# %% [markdown]
# 1. Check the data for stationary
#
# Hypothesis Dickey Fuller Test
# * H0 >> unit root = 1 (Data not stationary)
# * H1 >> unit root < 1 (Data is stationary)
#
# 1. AR -> P -> PACF
# 2. I -> d -> no of times differencing
# 3. MA -> q -> ACF

# %%
import statsmodels.api as sms

# %%
df1.isnull().sum()
# Out:
# Month          0
# #Passengers    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df1['Month'] = pd.to_datetime(df1.Month)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    datetime64[ns]
#  1   #Passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
df1.set_index('Month', inplace=True)

# %%
df1.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
df1.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def adf_test(series):
    result = adfuller(series)
    print('ADF Statistics: {}'.format(result[0]))
    print('p - value: {}'.format(result[1]))
    if result[1] <= 0.05:
        print('Strong evidence against the null hypothesis, reject null hypothesis. Data has no unit root and is stationary')
    else:
        print('Weak evidence against the null hypothesis, time series has a unit root, indicatiing it is a non stationary')

# %%
adf_test(df1['#Passengers'])
# Out:
# ADF Statistics: 0.8153688792060482
# p - value: 0.991880243437641
# Weak evidence against the null hypothesis, time series has a unit root, indicatiing it is a non stationary

# %%
# Use Differencing techniques

df1['#Passengers 1st difference'] = df1['#Passengers'] - df1['#Passengers'].shift(1)

# %%
df1.head()
# Out:
#             #Passengers  #Passengers 1st difference
# Month
# 1949-01-01          112                         NaN
# 1949-02-01          118                         6.0
# 1949-03-01          132                        14.0
# 1949-04-01          129                        -3.0
# 1949-05-01          121                        -8.0

# %%
adf_test(df1['#Passengers 1st difference'].dropna())
# Out:
# ADF Statistics: -2.8292668241699994
# p - value: 0.0542132902838255
# Weak evidence against the null hypothesis, time series has a unit root, indicatiing it is a non stationary

# %%
# Use Differencing techniques

df1['#Passengers 2nd difference'] = df1['#Passengers 1st difference'] - df1['#Passengers 1st difference'].shift(1)

# %%
df1.head()
# Out:
#             #Passengers  #Passengers 1st difference  \
# Month
# 1949-01-01          112                         NaN
# 1949-02-01          118                         6.0
# 1949-03-01          132                        14.0
# 1949-04-01          129                        -3.0
# 1949-05-01          121                        -8.0
#
#             #Passengers 2nd difference
# Month
# 1949-01-01                         NaN
# 1949-02-01                         NaN
# 1949-03-01                         8.0
# 1949-04-01                       -17.0
# 1949-05-01                        -5.0

# %%
adf_test(df1['#Passengers 2nd difference'].dropna())
# Out:
# ADF Statistics: -16.384231542468505
# p - value: 2.7328918500142407e-29
# Strong evidence against the null hypothesis, reject null hypothesis. Data has no unit root and is stationary

# %%
## 12 months

df1['#Passengers 12th difference'] = df1['#Passengers'] - df1['#Passengers'].shift(12)

# %%
df1.head()
# Out:
#             #Passengers  #Passengers 1st difference  \
# Month
# 1949-01-01          112                         NaN
# 1949-02-01          118                         6.0
# 1949-03-01          132                        14.0
# 1949-04-01          129                        -3.0
# 1949-05-01          121                        -8.0
#
#             #Passengers 2nd difference  #Passengers 12th difference
# Month
# 1949-01-01                         NaN                          NaN
# 1949-02-01                         NaN                          NaN
# 1949-03-01                         8.0                          NaN
# 1949-04-01                       -17.0                          NaN
# 1949-05-01                        -5.0                          NaN

# %%
adf_test(df1['#Passengers 12th difference'].dropna())
# Out:
# ADF Statistics: -3.383020726492481
# p - value: 0.011551493085514954
# Strong evidence against the null hypothesis, reject null hypothesis. Data has no unit root and is stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
acf = plot_acf(df1['#Passengers 2nd difference'].dropna())

# %%
acf_12 = plot_acf(df1['#Passengers 12th difference'].dropna())

# %%
result = plot_pacf(df1['#Passengers 2nd difference'].dropna())
# Out:
# C:\Users\Thivyan\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
result_12 = plot_pacf(df1['#Passengers 12th difference'].dropna())

# %%
from datetime import datetime, timedelta

# %%
train_dataset_end = datetime(1955, 12,1)
test_dataset_end = datetime(1960,12,1)

# %%
train_data = df1[:train_dataset_end]
test_data = df1[train_dataset_end+timedelta(days=1):test_dataset_end]

# %%
# Prediction
pred_start_date = test_data.index[0]
pred_end_date = test_data.index[-1]

# %%
test_data
# Out:
#             #Passengers  #Passengers 1st difference  \
# Month
# 1956-01-01          284                         6.0
# 1956-02-01          277                        -7.0
# 1956-03-01          317                        40.0
# 1956-04-01          313                        -4.0
# 1956-05-01          318                         5.0
# 1956-06-01          374                        56.0
# 1956-07-01          413                        39.0
# 1956-08-01          405                        -8.0
# 1956-09-01          355                       -50.0
# 1956-10-01          306                       -49.0
# 1956-11-01          271                       -35.0
# 1956-12-01          306                        35.0
# 1957-01-01          315                         9.0
# 1957-02-01          301                       -14.0
# 1957-03-01          356                        55.0
# 1957-04-01          348                        -8.0
# 1957-05-01          355                         7.0
# ...

# %%
# Create an ARIMA model
from statsmodels.tsa.arima.model import ARIMA

# %%
train_data
# Out:
#             #Passengers  #Passengers 1st difference  \
# Month
# 1949-01-01          112                         NaN
# 1949-02-01          118                         6.0
# 1949-03-01          132                        14.0
# 1949-04-01          129                        -3.0
# 1949-05-01          121                        -8.0
# ...                 ...                         ...
# 1955-08-01          347                       -17.0
# 1955-09-01          312                       -35.0
# 1955-10-01          274                       -38.0
# 1955-11-01          237                       -37.0
# 1955-12-01          278                        41.0
#
#             #Passengers 2nd difference  #Passengers 12th difference
# Month
# 1949-01-01                         NaN                          NaN
# 1949-02-01                         NaN                          NaN
# 1949-03-01                         8.0                          NaN
# ...

# %%
model_ARIMA = ARIMA(train_data['#Passengers'], order=(0,2,0))
# Out:
# C:\Users\Thivyan\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Thivyan\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Thivyan\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_ARIMA_fit = model_ARIMA.fit()

# %%
model_ARIMA_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:            #Passengers   No. Observations:                   84
# Model:                 ARIMA(0, 2, 0)   Log Likelihood                -385.792
# Date:                Tue, 03 Oct 2023   AIC                            773.584
# Time:                        19:52:27   BIC                            775.991
# Sample:                    01-01-1949   HQIC                           774.550
#                          - 12-01-1955
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2       714.5859    102.414      6.977      0.000     513.858     915.314
# ...
# Ljung-Box (L1) (Q):                   4.59   Jarque-Bera (JB):                 1.74
# ...

# %%
# Prediction
pred_start_date = test_data.index[0]
pred_end_date = test_data.index[-1]
print(pred_start_date)
print(pred_end_date)
# Out:
# 1956-01-01 00:00:00
# 1960-12-01 00:00:00

# %%
pred = model_ARIMA_fit.predict(start=pred_start_date, end=pred_end_date)
residuals = test_data['#Passengers'] - pred

# %%
residuals
# Out:
# Month
# 1956-01-01     -35.0
# 1956-02-01     -83.0
# 1956-03-01     -84.0
# 1956-04-01    -129.0
# 1956-05-01    -165.0
# 1956-06-01    -150.0
# 1956-07-01    -152.0
# 1956-08-01    -201.0
# 1956-09-01    -292.0
# 1956-10-01    -382.0
# 1956-11-01    -458.0
# 1956-12-01    -464.0
# 1957-01-01    -496.0
# 1957-02-01    -551.0
# 1957-03-01    -537.0
# 1957-04-01    -586.0
# 1957-05-01    -620.0
# 1957-06-01    -594.0
# 1957-07-01    -592.0
# 1957-08-01    -631.0
# 1957-09-01    -735.0
# 1957-10-01    -833.0
# 1957-11-01    -916.0
# 1957-12-01    -926.0
# 1958-01-01    -963.0
# 1958-02-01   -1026.0
# 1958-03-01   -1023.0
# 1958-04-01   -1078.0
# 1958-05-01   -1104.0
# 1958-06-01   -1073.0
# 1958-07-01   -1058.0
# 1958-08-01   -1085.0
# 1958-09-01   -1227.0
# 1958-10-01   -1313.0
# 1958-11-01   -1403.0
# 1958-12-01   -1417.0
# 1959-01-01   -1435.0
# 1959-02-01   -1494.0
# 1959-03-01   -1471.0
# 1959-04-01   -1522.0
# 1959-05-01   -1539.0
# 1959-06-01   -1528.0
# 1959-07-01   -1493.0
# ...

# %%
model_ARIMA_fit.resid.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
test_data['Predicted_ARIMA'] = pred
# Out:
# C:\Users\Thivyan\AppData\Local\Temp\ipykernel_8256\284031954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Predicted_ARIMA'] = pred

# %%
test_data[['#Passengers', 'Predicted_ARIMA']].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
## Create a SARIMAX model
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model_SARIMAX = SARIMAX(train_data['#Passengers'], order=(3,0,5), seasonal_order=(0,1,0,12))
# Out:
# C:\Users\Thivyan\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Thivyan\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_SARIMAX_fit = model_SARIMAX.fit()
# Out:
# C:\Users\Thivyan\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_SARIMAX_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:                         #Passengers   No. Observations:                   84
# Model:             SARIMAX(3, 0, 5)x(0, 1, [], 12)   Log Likelihood                -265.240
# Date:                             Tue, 03 Oct 2023   AIC                            548.481
# Time:                                     19:52:28   BIC                            568.971
# Sample:                                 01-01-1949   HQIC                           556.638
#                                       - 12-01-1955
# Covariance Type:                               opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5983      0.937      0.638      0.523      -1.239       2.436
# ...

# %%
test_data.tail()
# Out:
#             #Passengers  #Passengers 1st difference  \
# Month
# 1960-08-01          606                       -16.0
# 1960-09-01          508                       -98.0
# 1960-10-01          461                       -47.0
# 1960-11-01          390                       -71.0
# 1960-12-01          432                        42.0
#
#             #Passengers 2nd difference  #Passengers 12th difference  \
# Month
# 1960-08-01                      -103.0                         47.0
# 1960-09-01                       -82.0                         45.0
# 1960-10-01                        51.0                         54.0
# 1960-11-01                       -24.0                         28.0
# 1960-12-01                       113.0                         27.0
#
#             Predicted_ARIMA  Predicted_SARIMAX
# Month
# 1960-08-01           2574.0         460.254432
# 1960-09-01           2615.0         422.841887
# 1960-10-01           2656.0         381.654567
# ...

# %%
# Prediction
pred_start_date = test_data.index[0]
pred_end_date = test_data.index[-1]
print(pred_start_date)
print(pred_end_date)
# Out:
# 1956-01-01 00:00:00
# 1960-12-01 00:00:00

# %%
pred_SARIMAX = model_SARIMAX_fit.predict(start=pred_start_date, end=pred_end_date)
residuals_sarimax = test_data['#Passengers']-pred_SARIMAX

# %%
residuals_sarimax
# Out:
# Month
# 1956-01-01     -2.184793
# 1956-02-01     -4.277433
# 1956-03-01      7.083579
# 1956-04-01      2.323536
# 1956-05-01      6.665437
# 1956-06-01     19.050824
# 1956-07-01      9.602799
# 1956-08-01     19.929765
# 1956-09-01      5.555569
# 1956-10-01     -4.216910
# 1956-11-01     -1.562809
# 1956-12-01     -6.434417
# 1957-01-01     -4.955903
# 1957-02-01    -13.009835
# 1957-03-01     14.013334
# 1957-04-01      6.212605
# 1957-05-01     13.208787
# 1957-06-01     37.483313
# 1957-07-01     32.676961
# 1957-08-01     53.830762
# 1957-09-01     27.082239
# 1957-10-01     10.080944
# 1957-11-01      6.342316
# 1957-12-01     -1.808129
# 1958-01-01     -4.742385
# 1958-02-01    -20.120391
# 1958-03-01     -3.531080
# 1958-04-01    -16.697028
# 1958-05-01     -1.156379
# 1958-06-01     28.715305
# 1958-07-01     37.431516
# 1958-08-01     71.147906
# 1958-09-01      6.900082
# 1958-10-01      2.429479
# 1958-11-01     -7.830065
# 1958-12-01    -19.479370
# ...

# %%
model_SARIMAX_fit.resid.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
model_SARIMAX_fit.resid.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
test_data['Predicted_SARIMAX'] = pred_SARIMAX
# Out:
# C:\Users\Thivyan\AppData\Local\Temp\ipykernel_8256\1953269687.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Predicted_SARIMAX'] = pred_SARIMAX

# %%
test_data
# Out:
#             #Passengers  #Passengers 1st difference  \
# Month
# 1956-01-01          284                         6.0
# 1956-02-01          277                        -7.0
# 1956-03-01          317                        40.0
# 1956-04-01          313                        -4.0
# 1956-05-01          318                         5.0
# 1956-06-01          374                        56.0
# 1956-07-01          413                        39.0
# 1956-08-01          405                        -8.0
# 1956-09-01          355                       -50.0
# 1956-10-01          306                       -49.0
# 1956-11-01          271                       -35.0
# 1956-12-01          306                        35.0
# 1957-01-01          315                         9.0
# 1957-02-01          301                       -14.0
# 1957-03-01          356                        55.0
# 1957-04-01          348                        -8.0
# 1957-05-01          355                         7.0
# ...

# %%
test_data[['#Passengers', 'Predicted_ARIMA', 'Predicted_SARIMAX']].plot()
# Out:
# <Axes: xlabel='Month'>
