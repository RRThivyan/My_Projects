# %% [markdown]
# # Install Dependencies

# %%
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 88.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 84.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 29.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 31.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 92.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 87.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.0/220.0 kB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 115.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 7.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.39.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-exporter-otlp-proto-common==1.38.0, but you have opentelemetry-exporter-otlp-proto-common 1.39.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-proto==1.38.0, but you have opentelemetry-proto 1.39.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-sdk~=1.38.0, but you have opentelemetry-sdk 1.39.1 which is incompatible.

# %% [markdown]
# # Create Chromadb

# %%
# !python main.py --mode setup-db
# Out:
# ============================================================
# VECTOR DATABASE SETUP
# ============================================================
# ✅ Configuration validated successfully
# 🔧 Initializing Vector DB Creator...
#    Documents: /content/drive/MyDrive/Vertical_AI/rag_docs
#    Index: /content/drive/MyDrive/Vertical_AI/rag_index
# ============================================================
# CREATING VECTOR DATABASE
# ============================================================
#
# 📚 Loading documents...
#    Found 11 PDF files
#    ✅ Vehicle_Loans_MITC.pdf: 11 pages, 0 tables
#    ✅ Savings_Current_Accounts_MITC.pdf: 10 pages, 0 tables
#    ✅ Insurance_Products_Guide.pdf: 12 pages, 1 tables
#    ✅ Fixed_Recurring_Deposits_MITC.pdf: 10 pages, 1 tables
#    ✅ Digital_Banking_Services.pdf: 13 pages, 0 tables
#    ✅ Unsecured_personal_loans.pdf: 2 pages, 3 tables
#    ✅ Personal_Loans_scheme.pdf: 5 pages, 0 tables
#    ✅ SBI_SCHOLAR_LOAN_MITC.pdf: 3 pages, 4 tables
#    ✅ Credit_Cards_MITC.pdf: 9 pages, 0 tables
#    ✅ Personal_Loans_MITC.pdf: 2 pages, 5 tables
#    ✅ Master_circular_on_home_loans.pdf: 8 pages, 5 tables
#
#    📊 Total: 11 documents, 19 tables
#
# 📝 Creating chunks...
#    Chunk size: 1000
#    Overlap: 200
#    ✅ Created 62 chunks (19 with tables)
#
# 🔄 Creating embeddings...
#    Model: BAAI/bge-base-en-v1.5
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 702.36it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-base-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches: 100% 2/2 [00:01<00:00,  1.42it/s]
#    ✅ Created 62 embeddings
#
# 💾 Storing in ChromaDB...
# Uploading: 100% 1/1 [00:00<00:00,  6.03it/s]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Vertical_AI/bfsi_assistant/main.py", line 164, in <module>
#     setup_vector_db()
#   File "/content/drive/MyDrive/Vertical_AI/bfsi_assistant/main.py", line 133, in setup_vector_db
#     stats = creator.create_database()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/Vertical_AI/bfsi_assistant/vector_db_creator.py", line 631, in create_database
#     self.store_in_chromadb()
#   File "/content/drive/MyDrive/Vertical_AI/bfsi_assistant/vector_db_creator.py", line 583, in store_in_chromadb
#     self.chroma_client.persist()
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'Client' object has no attribute 'persist'

# %% [markdown]
# # Gradio UI

# %%
# !python main.py --mode ui
# Out:
# ============================================================
# BFSI CALL CENTER AI ASSISTANT
# ============================================================
#
# 📋 Validating configuration...
# ✅ Configuration validated successfully
# ============================================================
# CONFIGURATION
# ============================================================
# Dataset: /content/drive/MyDrive/Vertical_AI/bfsi_cleaned_dataset.json
# Documents: /content/drive/MyDrive/Vertical_AI/rag_docs
# Index: /content/drive/MyDrive/Vertical_AI/rag_index
# Model: LoRA Adapter
# Model Path: /content/drive/MyDrive/Vertical_AI/phi35-bfsi-lora
# ============================================================
#
# 🚀 Initializing system...
# ============================================================
# INITIALIZING BFSI ORCHESTRATOR
# ============================================================
#
# ============================================================
# 🔧 Initializing Tier 1 (Dataset Matcher)...
#    Threshold: 0.72
#    ✅ Loaded 524 records
#    📊 Loading model: all-MiniLM-L6-v2
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 103/103 [00:00<00:00, 721.29it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#    🔄 Creating embeddings...
#    ✅ Embeddings created: (524, 384)
# ✅ Tier 1 ready
#
# ============================================================
# 🔧 Initializing Tier 2 (Fine-tuned SLM)...
#    Model: microsoft/Phi-3.5-mini-instruct
#    Mode: LoRA Adapter
# This model config has set a `rope_parameters['original_max_position_embeddings']` field, to be used together with `max_position_embeddings` to determine a scaling factor. Please set the `factor` field of `rope_parameters`with this ratio instead -- we recommend the use of this field over `original_max_position_embeddings`, as it is compatible with most model architectures.
#    📂 Loading base model...
# `torch_dtype` is deprecated! Use `dtype` instead!
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# Loading weights: 100% 195/195 [00:30<00:00,  6.30it/s, Materializing param=model.norm.weight]
#    📂 Loading LoRA adapter...
# /usr/local/lib/python3.12/dist-packages/peft/tuners/tuners_utils.py:1225: UserWarning: Model has `tie_word_embeddings=True` and a tied layer is part of the adapter, but `ensure_weight_tying` is not set to True. This can lead to complications, for example when merging the adapter or converting your model to formats other than safetensors. Check the discussion here: https://github.com/huggingface/peft/issues/2777
#   warnings.warn(msg)
#    ✅ Model loaded on cuda:0
# ✅ Tier 2 ready
#
# ============================================================
# 🔧 Initializing Tier 3 (RAG System)...
#    📂 Loading vector database...
#    ✅ Found collection: bfsi_docs_final
#    ✅ Loaded 62 chunks
#    🔄 Creating BM25 index...
#    ✅ BM25 index created
#    📊 Loading models...
# Loading weights: 100% 199/199 [00:00<00:00, 662.91it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-base-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# config.json: 100% 799/799 [00:00<00:00, 4.56MB/s]
# model.safetensors: 100% 1.11G/1.11G [00:08<00:00, 129MB/s]
# Loading weights: 100% 201/201 [00:00<00:00, 842.21it/s, Materializing param=roberta.encoder.layer.11.output.dense.weight]
# XLMRobertaForSequenceClassification LOAD REPORT from: BAAI/bge-reranker-base
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json: 100% 443/443 [00:00<00:00, 2.71MB/s]
# sentencepiece.bpe.model: 100% 5.07M/5.07M [00:00<00:00, 9.42MB/s]
# tokenizer.json: 100% 17.1M/17.1M [00:00<00:00, 33.9MB/s]
# special_tokens_map.json: 100% 279/279 [00:00<00:00, 1.84MB/s]
# README.md: 34.1kB [00:00, 66.6MB/s]
#    ✅ Models loaded
# ✅ Tier 3 ready
#
# ============================================================
# ✅ ALL TIERS INITIALIZED
# ============================================================
#
# 📊 System Configuration:
#    • Tier 1: 524 dataset records
#    • Tier 2: available
#    • Tier 3: 62 chunks, 19 tables
#
# 🎯 Expected Coverage:
#    • Tier 1: ~70% (instant)
#    • Tier 2: ~20% (fast)
#    • Tier 3: ~10% (comprehensive)
#
# ============================================================
# ✅ SYSTEM READY
# ============================================================
#
# 🌐 Starting Gradio UI...
#
# ============================================================
# 🚀 LAUNCHING GRADIO INTERFACE
# ============================================================
# Share: True
# Debug: True
# Port: 7860
# ============================================================
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://9b1d57f567c9ecacf3.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# WARNING:transformers_modules.microsoft.Phi_hyphen_3_dot_5_hyphen_mini_hyphen_instruct.2fe192450127e6a83f7441aef6e3ca586c338b77.modeling_phi3:You are not running the flash-attention implementation, expect numerical differences.
# Keyboard interruption in main thread... closing server.
# Killing tunnel 0.0.0.0:7860 <> https://9b1d57f567c9ecacf3.gradio.live
